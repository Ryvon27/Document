# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryvon27/Document/blob/main/Inling_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Lakukan import Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#Lakukan drive mounting agar direktori G drive bisa kita akses
from google.colab import drive
drive.mount('/content/drive')
#Kita minimalisir error messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Kita create suatu dataset kecil untuk latihan
df = pd.DataFrame({'kolom 1':['a','b','c'], 'kolom 2':[21, 32, 21], 'kolom 3':[120, 120, 302]})
df
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a       21      120
# 1       b       32      120
# 2       c       21      302

# %%
df.columns
# Out:
# Index(['kolom 1', 'kolom 2', 'kolom 3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df['kolom 2'].sum()
# Out:
# 74

# %%
df['kolom 2'].mean()
# Out:
# 24.666666666666668

# %%
def rumus(y):
  return y**2 + y + 2

df['kolom 3'] = df['kolom 3'].apply(rumus)
df
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a       21    14522
# 1       b       32    14522
# 2       c       21    91508

# %%
df['kolom 3'] = df['kolom 3']**0.5
df
# Out:
#   kolom 1  kolom 2     kolom 3
# 0       a       21  120.507261
# 1       b       32  120.507261
# 2       c       21  302.502893

# %%
df['kolom 2'].unique()
# Out:
# array([21, 32])

# %%
df['kolom 2'].nunique()
# Out:
# 2

# %%
df['kolom 2'].value_counts()
# Out:
# kolom 2
# 21    2
# 32    1
# Name: count, dtype: int64

# %%
df.sort_values(by = 'kolom 2')
# Out:
#   kolom 1  kolom 2     kolom 3
# 0       a       21  120.507261
# 2       c       21  302.502893
# 1       b       32  120.507261

# %%
df = pd.DataFrame({'kolom 1' : ['a','b','c'], 'kolom 2':[21, 32, np.nan], 'kolom 3' : [120, 120, np.nan]})
df
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a     21.0    120.0
# 1       b     32.0    120.0
# 2       c      NaN      NaN

# %%
df.isnull()
# Out:
#    kolom 1  kolom 2  kolom 3
# 0    False    False    False
# 1    False    False    False
# 2    False     True     True

# %%
df.fillna(1000)
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a     21.0    120.0
# 1       b     32.0    120.0
# 2       c   1000.0   1000.0

# %%
df.fillna('kosong')
# Out:
#   kolom 1 kolom 2 kolom 3
# 0       a    21.0   120.0
# 1       b    32.0   120.0
# 2       c  kosong  kosong

# %%
df.dropna()
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a     21.0    120.0
# 1       b     32.0    120.0

# %%
df.at[3, 'kolom 1'] = 'd'; df.at[3, 'kolom 2'] = np.nan; df.at[3, 'kolom 3'] = 90
df
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a     21.0    120.0
# 1       b     32.0    120.0
# 2       c      NaN      NaN
# 3       d      NaN     90.0

# %%
df.drop(columns=['kolom 2', 'kolom 3'])
# Out:
#   kolom 1
# 0       a
# 1       b
# 2       c
# 3       d

# %%
df.drop(index=3)
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a     21.0    120.0
# 1       b     32.0    120.0
# 2       c      NaN      NaN

# %%
df
# Out:
#   kolom 1  kolom 2  kolom 3
# 0       a     21.0    120.0
# 1       b     32.0    120.0
# 2       c      NaN      NaN
# 3       d      NaN     90.0

# %%
#Hapus suatu kolom dan simpan
df = df.drop(columns=['kolom 3'])
df
# Out:
#   kolom 1  kolom 2
# 0       a     21.0
# 1       b     32.0
# 2       c      NaN
# 3       d      NaN

# %%
df.drop(index = 3)
# Out:
#   kolom 1  kolom 2
# 0       a     21.0
# 1       b     32.0
# 2       c      NaN

# %%
df.to_csv('data_latihan.csv')

# %%
#Pertama, kita baca sebuah file excel dan kita konversikan ke csv file
file = pd.read_excel('/content/drive/MyDrive/infling/Data/M03_missingdata.xlsx')

# %%
file.to_csv(r'M03_missingdata.csv', index = None, header=True)

# %%
df_xlsx = pd.read_excel('/content/drive/MyDrive/infling/Data/M03_missingdata.xlsx')

# %%
df_csv = pd.read_csv('M03_missingdata.csv')

# %%
df_xlsx
# Out:
#     Date  Temperature
# 0      1        23.40
# 1      2        23.40
# 2      3        23.50
# 3      4        24.70
# 4      5        24.80
# 5      6        23.90
# 6      7        24.00
# 7      8        24.90
# 8      9        25.00
# 9     10          NaN
# 10    11        24.40
# 11    12        24.50
# 12    13        24.60
# 13    14        24.60
# 14    15        24.80
# 15    16        25.10
# 16    17        25.00
# 17    18        25.10
# 18    19        25.15
# 19    20        25.20

# %%
df_csv
# Out:
#     Date  Temperature
# 0      1        23.40
# 1      2        23.40
# 2      3        23.50
# 3      4        24.70
# 4      5        24.80
# 5      6        23.90
# 6      7        24.00
# 7      8        24.90
# 8      9        25.00
# 9     10          NaN
# 10    11        24.40
# 11    12        24.50
# 12    13        24.60
# 13    14        24.60
# 14    15        24.80
# 15    16        25.10
# 16    17        25.00
# 17    18        25.10
# 18    19        25.15
# 19    20        25.20

# %%
df_xlsx.at[19, 'Temperature'] = 10
df_xlsx
# Out:
#     Date  Temperature
# 0      1        23.40
# 1      2        23.40
# 2      3        23.50
# 3      4        24.70
# 4      5        24.80
# 5      6        23.90
# 6      7        24.00
# 7      8        24.90
# 8      9        25.00
# 9     10          NaN
# 10    11        24.40
# 11    12        24.50
# 12    13        24.60
# 13    14        24.60
# 14    15        24.80
# 15    16        25.10
# 16    17        25.00
# 17    18        25.10
# 18    19        25.15
# 19    20        10.00

# %%
df_csv.at[19, 'Temperature'] =10
df_csv
# Out:
#     Date  Temperature
# 0      1        23.40
# 1      2        23.40
# 2      3        23.50
# 3      4        24.70
# 4      5        24.80
# 5      6        23.90
# 6      7        24.00
# 7      8        24.90
# 8      9        25.00
# 9     10          NaN
# 10    11        24.40
# 11    12        24.50
# 12    13        24.60
# 13    14        24.60
# 14    15        24.80
# 15    16        25.10
# 16    17        25.00
# 17    18        25.10
# 18    19        25.15
# 19    20        10.00

# %%
#Cek, sebutkan nilai pada baris nomor ke sekian pada kolom tertentu.
df_csv.at[19, 'Temperature']
# Out:
# 10.0

# %%
df = pd.read_csv('M03_missingdata.csv')

# %%
#Tunjukkan nomer baris pertama dan terakhir. FYI
awal = df.index.start
akhir = df.index.stop - 1
print(awal)
print(akhir)
# Out:
# 0
# 19

# %%
#Cari nilai m statik
x_awal  = df.at[awal, 'Date']
x_akhir = df.at[akhir, 'Date']
y_awal  = df.at[awal, 'Temperature']
y_akhir = df.at[akhir, 'Temperature']

m = (y_akhir - y_awal) / (x_akhir - x_awal)

print(x_awal, x_akhir)
print(y_awal, y_akhir)
print(m)
# Out:
# 1 20
# 23.4 25.2
# 0.09473684210526319

# %%
for n in range(awal, akhir+1):
  xn = df.at[n,'Date']
  df.at[n, 'Temp_SLR'] = y_awal + m * (xn - x_awal)

  number = df.at[n, 'Temperature']
  if np.isnan(number) == True:
    df.at[n, 'Temperature'] = df.at[n, 'Temp_SLR']

df
# Out:
#     Date  Temperature   Temp_SLR
# 0      1    23.400000  23.400000
# 1      2    23.400000  23.494737
# 2      3    23.500000  23.589474
# 3      4    24.700000  23.684211
# 4      5    24.800000  23.778947
# 5      6    23.900000  23.873684
# 6      7    24.000000  23.968421
# 7      8    24.900000  24.063158
# 8      9    25.000000  24.157895
# 9     10    24.252632  24.252632
# 10    11    24.400000  24.347368
# 11    12    24.500000  24.442105
# 12    13    24.600000  24.536842
# 13    14    24.600000  24.631579
# 14    15    24.800000  24.726316
# 15    16    25.100000  24.821053
# 16    17    25.000000  24.915789
# 17    18    25.100000  25.010526
# 18    19    25.150000  25.105263
# 19    20    25.200000  25.200000

# %%
plt.plot(df['Date'], df['Temperature'])
plt.plot(df['Date'], df['Temp_SLR'])
plt.legend(['Temperature Riil', 'Prediksi Temperature (SLR)'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
for n in range(awal, akhir+1):
  df.at[n,'Komp_RMSE_SLR'] = (df.at[n,'Temperature'] - df.at[n,'Temp_SLR']) ** 2

df
# Out:
#     Date  Temperature   Temp_SLR  Komp_RMSE_SLR
# 0      1    23.400000  23.400000       0.000000
# 1      2    23.400000  23.494737       0.008975
# 2      3    23.500000  23.589474       0.008006
# 3      4    24.700000  23.684211       1.031828
# 4      5    24.800000  23.778947       1.042548
# 5      6    23.900000  23.873684       0.000693
# 6      7    24.000000  23.968421       0.000997
# 7      8    24.900000  24.063158       0.700305
# 8      9    25.000000  24.157895       0.709141
# 9     10    24.252632  24.252632       0.000000
# 10    11    24.400000  24.347368       0.002770
# 11    12    24.500000  24.442105       0.003352
# 12    13    24.600000  24.536842       0.003989
# 13    14    24.600000  24.631579       0.000997
# 14    15    24.800000  24.726316       0.005429
# 15    16    25.100000  24.821053       0.077812
# 16    17    25.000000  24.915789       0.007091
# 17    18    25.100000  25.010526       0.008006
# 18    19    25.150000  25.105263       0.002001
# 19    20    25.200000  25.200000       0.000000

# %%
RMSE_SLR = (df['Komp_RMSE_SLR'].mean()) ** 0.5
RMSE_SLR
# Out:
# 0.4250847235089325

# %%
df.to_csv('M05_Result_SLR.csv')

# %%
df = pd.read_csv('M03_missingdata.csv')
df
# Out:
#     Date  Temperature
# 0      1        23.40
# 1      2        23.40
# 2      3        23.50
# 3      4        24.70
# 4      5        24.80
# 5      6        23.90
# 6      7        24.00
# 7      8        24.90
# 8      9        25.00
# 9     10          NaN
# 10    11        24.40
# 11    12        24.50
# 12    13        24.60
# 13    14        24.60
# 14    15        24.80
# 15    16        25.10
# 16    17        25.00
# 17    18        25.10
# 18    19        25.15
# 19    20        25.20

# %%
awal = df.index.start
akhir = df.index.stop - 1
print(awal)
print(akhir)
# Out:
# 0
# 19

# %%
#Cari nilai x_awal dan y_awal
x_awal  = df.at[awal, 'Date']
x_akhir = df.at[akhir, 'Date']
y_awal  = df.at[awal, 'Temperature']
y_akhir = df.at[akhir, 'Temperature']
#m = (y_akhir - y_awal) / (x_akhir - x_awal)
print(x_awal, x_akhir)
print(y_awal, y_akhir)
# Out:
# 1 20
# 23.4 25.2

# %%
#Terapkan rumus DLR untuk setiap baris, manfaatkan iterasi dengan looping.
for n in range(awal, awal+2):
  df.at[n, 'm_DLR'] = 0
  df.at[n, 'Temp_DLR'] = df.at[n, 'Temperature']

for n in range(awal+2, akhir+1):
  df.at[n, 'm_DLR']    =  (df.at[n-1, 'Temperature'] - df.at[awal, 'Temperature'])  /  (df.at[n-1, 'Date'] - df.at[awal, 'Date'])
  df.at[n, 'Temp_DLR'] =  y_awal + df.at[n, 'm_DLR'] * (df.at[n, 'Date'] - x_awal)

  #Sekarang kita cek apakah baris ke-n ini merupakan lokasi missing data (NaN). Jika iya, ganti NaN dengan data 'Temp_DLR'
  number = df.at[n, 'Temperature']
  if np.isnan(number) == True:
    df.at[n, 'Temperature'] = df.at[n, 'Temp_DLR']

df
# Out:
#     Date  Temperature     m_DLR   Temp_DLR
# 0      1        23.40  0.000000  23.400000
# 1      2        23.40  0.000000  23.400000
# 2      3        23.50  0.000000  23.400000
# 3      4        24.70  0.050000  23.550000
# 4      5        24.80  0.433333  25.133333
# 5      6        23.90  0.350000  25.150000
# 6      7        24.00  0.100000  24.000000
# 7      8        24.90  0.100000  24.100000
# 8      9        25.00  0.214286  25.114286
# 9     10        25.20  0.200000  25.200000
# 10    11        24.40  0.200000  25.400000
# 11    12        24.50  0.100000  24.500000
# 12    13        24.60  0.100000  24.600000
# 13    14        24.60  0.100000  24.700000
# 14    15        24.80  0.092308  24.692308
# 15    16        25.10  0.100000  24.900000
# 16    17        25.00  0.113333  25.213333
# 17    18        25.10  0.100000  25.100000
# 18    19        25.15  0.100000  25.200000
# 19    20        25.20  0.097222  25.247222

# %%
#Visualisasikan temperatur riil dan temperatur hasil dari metode DLR
plt.plot(df['Date'], df['Temperature'])
plt.plot(df['Date'], df['Temp_DLR'])
plt.legend(['Temperatur Riil', 'Prediksi Temperature dengan DLR'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
#Hitung komponen RMSE dan tambahkan satu kolom untuk menampungnya
for n in range(awal, akhir+1):
  df.at[n,'Komp_RMSE_DLR'] = (df.at[n,'Temperature'] - df.at[n,'Temp_DLR']) ** 2

df
# Out:
#     Date  Temperature     m_DLR   Temp_DLR  Komp_RMSE_DLR
# 0      1        23.40  0.000000  23.400000       0.000000
# 1      2        23.40  0.000000  23.400000       0.000000
# 2      3        23.50  0.000000  23.400000       0.010000
# 3      4        24.70  0.050000  23.550000       1.322500
# 4      5        24.80  0.433333  25.133333       0.111111
# 5      6        23.90  0.350000  25.150000       1.562500
# 6      7        24.00  0.100000  24.000000       0.000000
# 7      8        24.90  0.100000  24.100000       0.640000
# 8      9        25.00  0.214286  25.114286       0.013061
# 9     10        25.20  0.200000  25.200000       0.000000
# 10    11        24.40  0.200000  25.400000       1.000000
# 11    12        24.50  0.100000  24.500000       0.000000
# 12    13        24.60  0.100000  24.600000       0.000000
# 13    14        24.60  0.100000  24.700000       0.010000
# 14    15        24.80  0.092308  24.692308       0.011598
# 15    16        25.10  0.100000  24.900000       0.040000
# 16    17        25.00  0.113333  25.213333       0.045511
# 17    18        25.10  0.100000  25.100000       0.000000
# 18    19        25.15  0.100000  25.200000       0.002500
# 19    20        25.20  0.097222  25.247222       0.002230

# %%
#Hitung RMSE dari temperature DLR berdasarkan tabel di atas.
RSME_DLR = (df['Komp_RMSE_DLR'].mean()) ** 0.5
RSME_DLR
# Out:
# 0.48841637043201774

# %%
#Simpan df ke file csv
df.to_csv('M05_Result_SLR')

# %%
#Bandingkan RMSE dari metode SLR dan DLR
print('RMSE_SLR =', RMSE_SLR)
print('RMSE_DLR =', RMSE_DLR)
